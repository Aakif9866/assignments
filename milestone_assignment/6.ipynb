# %%
class MenuItem:
    """
    Represents a menu item with encapsulated attributes and methods.
    """

    def __init__(self, name, description, price, category):
        self.__unique_id = self.__generate_unique_id()  # Private attribute for unique ID
        self.__name = name
        self.__description = description
        self.__price = price
        self.__category = category

    def __generate_unique_id(self):
        # Implement a method to generate a unique ID (e.g., using a timestamp or random number)
        pass

    def get_name(self):
        """Returns the menu item's name."""
        return self.__name

    def get_description(self):
        """Returns the menu item's description."""
        return self.__description

    def get_price(self):
        """Returns the menu item's price."""
        return self.__price

    def get_category(self):
        """Returns the menu item's category."""
        return self.__category

    def update_info(self, new_name=None, new_description=None, new_price=None, new_category=None):
        """Updates the menu item's information."""
        if new_name is not None:
            self.__name = new_name
        if new_description is not None:
            self.__description = new_description
        if new_price is not None:
            self.__price = new_price
        if new_category is not None:
            self.__category = new_category

    # Implement methods for adding, removing, and listing menu items
