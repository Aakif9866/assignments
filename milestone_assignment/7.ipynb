# %%
class Room:
    """
    Represents a hotel room with encapsulated attributes and methods.
    """

    def __init__(self, room_number, room_type, rate):
        self.__unique_id = self.__generate_unique_id()  # Private attribute for unique ID
        self.__room_number = room_number
        self.__room_type = room_type
        self.__rate = rate
        self.__is_available = True

    def __generate_unique_id(self):
        # Implement a method to generate a unique ID (e.g., using a timestamp or random number)
        pass

    def get_room_number(self):
        """Returns the room number."""
        return self.__room_number

    def get_room_type(self):
        """Returns the room type."""
        return self.__room_type

    def get_rate(self):
        """Returns the room rate."""
        return self.__rate

    def is_available(self):
        """Checks if the room is available."""
        return self.__is_available

    def book_room(self):
        """Books the room if it's available."""
        if self.is_available():
            self.__is_available = False
            print(f"Room {self.get_room_number()} has been booked.")
        else:
            print(f"Room {self.get_room_number()} is not available.")

    # Implement methods for checking in and checking out guests
