# %%
class Flight:
    """
    Represents a flight with encapsulated attributes and methods.
    """

    def __init__(self, flight_number, departure_airport, arrival_airport, departure_time, arrival_time):
        self.__unique_id = self.__generate_unique_id()  # Private attribute for unique ID
        self.__flight_number = flight_number
        self.__departure_airport = departure_airport
        self.__arrival_airport = arrival_airport
        self.__departure_time = departure_time
        self.__arrival_time = arrival_time
        self.__available_seats = 100  # Assuming 100 available seats initially

    def __generate_unique_id(self):
        # Implement a method to generate a unique ID (e.g., using a timestamp or random number)
        pass

    def get_flight_number(self):
        """Returns the flight number."""
        return self.__flight_number

    def get_departure_airport(self):
        """Returns the departure airport."""
        return self.__departure_airport

    def get_arrival_airport(self):
        """Returns the arrival airport."""
        return self.__arrival_airport

    def get_departure_time(self):
        """Returns the departure time."""
        return self.__departure_time

    def get_arrival_time(self):
        """Returns the arrival time."""
        return self.__arrival_time

    def get_available_seats(self):
        """Returns the number of available seats."""
        return self.__available_seats

    def book_seat(self):
        """Books a seat if available."""
        if self.__available_seats > 0:
            self.__available_seats -= 1
            print(f"Seat booked on flight {self.get_flight_number()}. Remaining seats: {self.get_available_seats()}")
        else:
            print(f"Flight {self.get_flight_number()} is fully booked.")

    # Implement methods for canceling reservations and getting remaining available seats
