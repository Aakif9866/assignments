# %%
class Member:
    """
    Represents a fitness club member with encapsulated attributes and methods.
    """

    def __init__(self, name, age, membership_type):
        self.__unique_id = self.__generate_unique_id()  # Private attribute for unique ID
        self.__name = name
        self.__age = age
        self.__membership_type = membership_type
        self.__membership_status = "Active"

    def __generate_unique_id(self):
        # Implement a method to generate a unique ID (e.g., using a timestamp or random number)
        pass

    def get_name(self):
        """Returns the member's name."""
        return self.__name

    def get_age(self):
        """Returns the member's age."""
        return self.__age

    def get_membership_type(self):
        """Returns the member's membership type."""
        return self.__membership_type

    def get_membership_status(self):
        """Returns the member's membership status."""
        return self.__membership_status

    def renew_membership(self):
        """Renews the member's membership."""
        self.__membership_status = "Active"
        print(f"{self.get_name()}'s membership has been renewed.")

    # Implement methods for registering new members and canceling memberships
